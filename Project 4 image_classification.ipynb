# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelBinarizer


def _load_label_names():
    """
    Load the label names from file
    """
    return ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']


def load_cfar10_batch(cifar10_dataset_folder_path, batch_id):
    """
    Load a batch of the dataset
    """
    with open(cifar10_dataset_folder_path + '/data_batch_' + str(batch_id), mode='rb') as file:
        batch = pickle.load(file, encoding='latin1')

    features = batch['data'].reshape((len(batch['data']), 3, 32, 32)).transpose(0, 2, 3, 1)
    labels = batch['labels']

    return features, labels


def display_stats(cifar10_dataset_folder_path, batch_id, sample_id):
    """
    Display Stats of the the dataset
    """
    batch_ids = list(range(1, 6))

    if batch_id not in batch_ids:
        print('Batch Id out of Range. Possible Batch Ids: {}'.format(batch_ids))
        return None

    features, labels = load_cfar10_batch(cifar10_dataset_folder_path, batch_id)

    if not (0 <= sample_id < len(features)):
        print('{} samples in batch {}.  {} is out of range.'.format(len(features), batch_id, sample_id))
        return None

    print('\nStats of batch {}:'.format(batch_id))
    print('Samples: {}'.format(len(features)))
    print('Label Counts: {}'.format(dict(zip(*np.unique(labels, return_counts=True)))))
    print('First 20 Labels: {}'.format(labels[:20]))

    sample_image = features[sample_id]
    sample_label = labels[sample_id]
    label_names = _load_label_names()

    print('\nExample of Image {}:'.format(sample_id))
    print('Image - Min Value: {} Max Value: {}'.format(sample_image.min(), sample_image.max()))
    print('Image - Shape: {}'.format(sample_image.shape))
    print('Label - Label Id: {} Name: {}'.format(sample_label, label_names[sample_label]))
    plt.axis('off')
    plt.imshow(sample_image)


def _preprocess_and_save(normalize, one_hot_encode, features, labels, filename):
    """
    Preprocess data and save it to file
    """
    features = normalize(features)
    labels = one_hot_encode(labels)

    pickle.dump((features, labels), open(filename, 'wb'))


def preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode):
    """
    Preprocess Training and Validation Data
    """
    n_batches = 5
    valid_features = []
    valid_labels = []

    for batch_i in range(1, n_batches + 1):
        features, labels = load_cfar10_batch(cifar10_dataset_folder_path, batch_i)
        validation_count = int(len(features) * 0.1)

        # Prprocess and save a batch of training data
        _preprocess_and_save(
            normalize,
            one_hot_encode,
            features[:-validation_count],
            labels[:-validation_count],
            'preprocess_batch_' + str(batch_i) + '.p')

        # Use a portion of training batch for validation
        valid_features.extend(features[-validation_count:])
        valid_labels.extend(labels[-validation_count:])

    # Preprocess and Save all validation data
    _preprocess_and_save(
        normalize,
        one_hot_encode,
        np.array(valid_features),
        np.array(valid_labels),
        'preprocess_validation.p')

    with open(cifar10_dataset_folder_path + '/test_batch', mode='rb') as file:
        batch = pickle.load(file, encoding='latin1')

    # load the training data
    test_features = batch['data'].reshape((len(batch['data']), 3, 32, 32)).transpose(0, 2, 3, 1)
    test_labels = batch['labels']

    # Preprocess and Save all training data
    _preprocess_and_save(
        normalize,
        one_hot_encode,
        np.array(test_features),
        np.array(test_labels),
        'preprocess_training.p')


def batch_features_labels(features, labels, batch_size):
    """
    Split features and labels into batches
    """
    for start in range(0, len(features), batch_size):
        end = min(start + batch_size, len(features))
        yield features[start:end], labels[start:end]


def load_preprocess_training_batch(batch_id, batch_size):
    """
    Load the Preprocessed Training data and return them in batches of <batch_size> or less
    """
    filename = 'preprocess_batch_' + str(batch_id) + '.p'
    features, labels = pickle.load(open(filename, mode='rb'))

    # Return the training data in batches of size <batch_size> or less
    return batch_features_labels(features, labels, batch_size)


def display_image_predictions(features, labels, predictions):
    n_classes = 10
    label_names = _load_label_names()
    label_binarizer = LabelBinarizer()
    label_binarizer.fit(range(n_classes))
    label_ids = label_binarizer.inverse_transform(np.array(labels))

    fig, axies = plt.subplots(nrows=4, ncols=2)
    fig.tight_layout()
    fig.suptitle('Softmax Predictions', fontsize=20, y=1.1)

    n_predictions = 3
    margin = 0.05
    ind = np.arange(n_predictions)
    width = (1. - 2. * margin) / n_predictions

    for image_i, (feature, label_id, pred_indicies, pred_values) in enumerate(zip(features, label_ids, predictions.indices, predictions.values)):
        pred_names = [label_names[pred_i] for pred_i in pred_indicies]
        correct_name = label_names[label_id]

        axies[image_i][0].imshow(feature*255)
        axies[image_i][0].set_title(correct_name)
        axies[image_i][0].set_axis_off()

        axies[image_i][1].barh(ind + margin, pred_values[::-1], width)
        axies[image_i][1].set_yticks(ind + margin)
        axies[image_i][1].set_yticklabels(pred_names[::-1])
        axies[image_i][1].set_xticks([0, 0.5, 1.0])

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np

# Explore the dataset
batch_id = 3
sample_id = 5
display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 3:
# Samples: 10000
# Label Counts: {0: 994, 1: 1042, 2: 965, 3: 997, 4: 990, 5: 1029, 6: 978, 7: 1015, 8: 961, 9: 1029}
# First 20 Labels: [8, 5, 0, 6, 9, 2, 8, 3, 6, 2, 7, 4, 6, 9, 0, 0, 7, 3, 7, 2]
#
# Example of Image 5:
# Image - Min Value: 9 Max Value: 255
# Image - Shape: (32, 32, 3)
# Label - Label Id: 2 Name: bird

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize

# %%
import numpy as np
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    x = np.array(x)
    x_max = np.max(x)
    x_min = np.min(x)
    output = (x - x_min)/(x_max - x_min)
    return output

# %%
from sklearn import preprocessing
lb = preprocessing.LabelBinarizer()
lb.fit(range(10))
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    
    return lb.transform(x)

# %% [markdown]
# ### Randomize Data

# %%
preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %%
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %%
import tensorflow as tf

# %%
def neural_net_image_input(image_shape):
    """
    Return a Tensor for a bach of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    
    return tf.placeholder(tf.float32, shape = (None, image_shape[0], image_shape[1], image_shape[2]), name = 'x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    return tf.placeholder(tf.float32, shape = (None, n_classes), name = 'y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    return tf.placeholder(tf.float32, shape = (None), name = 'keep_prob')


tf.reset_default_graph()

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    shape_of_x_tensor = x_tensor.get_shape().as_list()
    F_W = tf.Variable(tf.truncated_normal([conv_ksize[0] ,conv_ksize[1] ,shape_of_x_tensor[-1] ,conv_num_outputs] 
                                          ,dtype=tf.float32, stddev=0.2))
    F_b = tf.Variable(tf.zeros([conv_num_outputs]  ,dtype=tf.float32))
    strides_conv = [1, conv_strides[0], conv_strides[1], 1]
    padding = 'SAME'
    output = tf.nn.conv2d(x_tensor, F_W, strides_conv, padding)
    output = tf.nn.bias_add(output, F_b)
    output = tf.nn.relu(output)
    ksize_maxpool = [1, pool_ksize[0], pool_ksize[1], 1]
    strides_maxpool = [1, pool_strides[0], pool_strides[1], 1]
    output = tf.nn.max_pool(output, ksize_maxpool, strides_maxpool, padding)
    
    return output

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    shape = x_tensor.get_shape().as_list()
    flat_dim = shape[1]*shape[2]*shape[3]
    output = tf.reshape(x_tensor, [-1, flat_dim])
    return output

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    shape = x_tensor.get_shape().as_list()
    weights= tf.Variable(tf.truncated_normal([shape[1], num_outputs] ,dtype=tf.float32, stddev=0.2))
    biases = tf.Variable(tf.zeros([num_outputs]  ,dtype=tf.float32))
    out = tf.add(tf.matmul(x_tensor, weights), biases)
    out = tf.nn.relu(out)
    return out

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    shape = x_tensor.get_shape().as_list()
    weights= tf.Variable(tf.truncated_normal([shape[1], num_outputs] ,dtype=tf.float32, stddev=0.2))
    biases = tf.Variable(tf.zeros([num_outputs]  ,dtype=tf.float32))
    out = tf.add(tf.matmul(x_tensor, weights), biases)
    return out

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """

    out = conv2d_maxpool(x, conv_num_outputs = 16, conv_ksize = (3,3), conv_strides = (1,1), pool_ksize=(2,2), pool_strides=(2,2))
    out = conv2d_maxpool(out, conv_num_outputs = 32, conv_ksize = (3,3), conv_strides = (1,1), pool_ksize=(2,2), pool_strides=(2,2))
    out = conv2d_maxpool(out, conv_num_outputs = 64, conv_ksize = (3,3), conv_strides = (1,1), pool_ksize=(2,2), pool_strides=(2,2))

    # Function Definition from Above:
    out = flatten(out)
    
    

    out = fully_conn(out, num_outputs = 64)
    out = tf.nn.dropout(out, keep_prob)
    out = fully_conn(out, num_outputs = 32)
    out = tf.nn.dropout(out, keep_prob)
    out = fully_conn(out, num_outputs = 16)
    #    Set this to the number of classes
    # Function Definition from Above:
    out = output(out, num_outputs = 10)

    return out


##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    session.run(optimizer, feed_dict={x:feature_batch, y:label_batch,keep_prob:keep_probability})

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    valid_acc = sess.run(accuracy, feed_dict={
                x: valid_features,
                y: valid_labels,
                keep_prob: 1.})
    train_acc = sess.run(accuracy, feed_dict={
                x: feature_batch,
                y: label_batch,
                keep_prob: 1.})
    train_cost = sess.run(cost, feed_dict={
                x: feature_batch,
                y: label_batch,
                keep_prob: 1.})
    print('Cost {::>8.5f}, Accuracy on Training {:.4f} -'
                  'Validation Accuracy: {:.4f}'.format(
                train_cost,
                train_acc,
                valid_acc))

# %%
epochs = 50
batch_size = 256
keep_probability = 0.6

# %%
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Cost :2.29493, Accuracy on Training 0.1750 -Validation Accuracy: 0.1374
# Epoch  2, CIFAR-10 Batch 1:  Cost :2.27247, Accuracy on Training 0.1750 -Validation Accuracy: 0.1692
# Epoch  3, CIFAR-10 Batch 1:  Cost :2.22933, Accuracy on Training 0.2000 -Validation Accuracy: 0.1760
# Epoch  4, CIFAR-10 Batch 1:  Cost :2.22412, Accuracy on Training 0.1250 -Validation Accuracy: 0.1894
# Epoch  5, CIFAR-10 Batch 1:  Cost :2.16202, Accuracy on Training 0.1750 -Validation Accuracy: 0.2182
# Epoch  6, CIFAR-10 Batch 1:  Cost :2.11171, Accuracy on Training 0.2000 -Validation Accuracy: 0.2422
# Epoch  7, CIFAR-10 Batch 1:  Cost :2.01399, Accuracy on Training 0.2750 -Validation Accuracy: 0.2692
# Epoch  8, CIFAR-10 Batch 1:  Cost :1.98558, Accuracy on Training 0.2500 -Validation Accuracy: 0.2816
# Epoch  9, CIFAR-10 Batch 1:  Cost :1.85702, Accuracy on Training 0.3250 -Validation Accuracy: 0.3060
# Epoch 10, CIFAR-10 Batch 1:  Cost :1.79663, Accuracy on Training 0.4500 -Validation Accuracy: 0.3090
# Epoch 11, CIFAR-10 Batch 1:  Cost :1.77465, Accuracy on Training 0.5000 -Validation Accuracy: 0.3136
# Epoch 12, CIFAR-10 Batch 1:  Cost :1.70105, Accuracy on Training 0.5000 -Validation Accuracy: 0.3448
# Epoch 13, CIFAR-10 Batch 1:  Cost :1.69862, Accuracy on Training 0.5250 -Validation Accuracy: 0.3748
# Epoch 14, CIFAR-10 Batch 1:  Cost :1.63101, Accuracy on Training 0.5500 -Validation Accuracy: 0.3910
# Epoch 15, CIFAR-10 Batch 1:  Cost :1.52394, Accuracy on Training 0.5500 -Validation Accuracy: 0.3690
# Epoch 16, CIFAR-10 Batch 1:  Cost :1.47828, Accuracy on Training 0.6000 -Validation Accuracy: 0.3940
# Epoch 17, CIFAR-10 Batch 1:  Cost :1.47436, Accuracy on Training 0.6000 -Validation Accuracy: 0.4082
# Epoch 18, CIFAR-10 Batch 1:  Cost :1.43875, Accuracy on Training 0.6000 -Validation Accuracy: 0.4134
# Epoch 19, CIFAR-10 Batch 1:  Cost :1.34462, Accuracy on Training 0.6500 -Validation Accuracy: 0.4122
# Epoch 20, CIFAR-10 Batch 1:  Cost :1.32775, Accuracy on Training 0.6000 -Validation Accuracy: 0.4194
# Epoch 21, CIFAR-10 Batch 1:  Cost :1.33257, Accuracy on Training 0.6250 -Validation Accuracy: 0.4296
# Epoch 22, CIFAR-10 Batch 1:  Cost :1.25678, Accuracy on Training 0.6250 -Validation Accuracy: 0.4428
# Epoch 23, CIFAR-10 Batch 1:  Cost :1.19700, Accuracy on Training 0.6000 -Validation Accuracy: 0.4556
# Epoch 24, CIFAR-10 Batch 1:  Cost :1.18502, Accuracy on Training 0.6000 -Validation Accuracy: 0.4564
# Epoch 25, CIFAR-10 Batch 1:  Cost :1.15173, Accuracy on Training 0.6500 -Validation Accuracy: 0.4606
# Epoch 26, CIFAR-10 Batch 1:  Cost :1.09551, Accuracy on Training 0.6750 -Validation Accuracy: 0.4508
# Epoch 27, CIFAR-10 Batch 1:  Cost :1.06957, Accuracy on Training 0.6500 -Validation Accuracy: 0.4690
# Epoch 28, CIFAR-10 Batch 1:  Cost :1.03376, Accuracy on Training 0.7000 -Validation Accuracy: 0.4662
# Epoch 29, CIFAR-10 Batch 1:  Cost :1.02957, Accuracy on Training 0.7500 -Validation Accuracy: 0.4688
# Epoch 30, CIFAR-10 Batch 1:  Cost :0.94473, Accuracy on Training 0.7000 -Validation Accuracy: 0.4882
# Epoch 31, CIFAR-10 Batch 1:  Cost :0.92329, Accuracy on Training 0.7500 -Validation Accuracy: 0.4894
# Epoch 32, CIFAR-10 Batch 1:  Cost :0.92028, Accuracy on Training 0.7750 -Validation Accuracy: 0.5002
# Epoch 33, CIFAR-10 Batch 1:  Cost :0.88095, Accuracy on Training 0.7750 -Validation Accuracy: 0.4922
# Epoch 34, CIFAR-10 Batch 1:  Cost :0.86363, Accuracy on Training 0.7000 -Validation Accuracy: 0.4932
# Epoch 35, CIFAR-10 Batch 1:  Cost :0.84458, Accuracy on Training 0.6750 -Validation Accuracy: 0.4900
# Epoch 36, CIFAR-10 Batch 1:  Cost :0.85101, Accuracy on Training 0.7250 -Validation Accuracy: 0.4986
# Epoch 37, CIFAR-10 Batch 1:  Cost :0.75868, Accuracy on Training 0.7000 -Validation Accuracy: 0.5056
# Epoch 38, CIFAR-10 Batch 1:  Cost :0.77929, Accuracy on Training 0.7500 -Validation Accuracy: 0.5026
# Epoch 39, CIFAR-10 Batch 1:  Cost :0.74779, Accuracy on Training 0.7250 -Validation Accuracy: 0.5114
# Epoch 40, CIFAR-10 Batch 1:  Cost :0.71996, Accuracy on Training 0.7250 -Validation Accuracy: 0.5142
# Epoch 41, CIFAR-10 Batch 1:  Cost :0.70079, Accuracy on Training 0.7500 -Validation Accuracy: 0.4936
# Epoch 42, CIFAR-10 Batch 1:  Cost :0.71448, Accuracy on Training 0.7000 -Validation Accuracy: 0.5116
# Epoch 43, CIFAR-10 Batch 1:  Cost :0.71198, Accuracy on Training 0.7500 -Validation Accuracy: 0.5112
# Epoch 44, CIFAR-10 Batch 1:  Cost :0.65190, Accuracy on Training 0.8000 -Validation Accuracy: 0.5054
# Epoch 45, CIFAR-10 Batch 1:  Cost :0.67261, Accuracy on Training 0.7750 -Validation Accuracy: 0.5086
# Epoch 46, CIFAR-10 Batch 1:  Cost :0.64662, Accuracy on Training 0.7500 -Validation Accuracy: 0.5202
# Epoch 47, CIFAR-10 Batch 1:  Cost :0.61769, Accuracy on Training 0.8250 -Validation Accuracy: 0.5194
# Epoch 48, CIFAR-10 Batch 1:  Cost :0.60687, Accuracy on Training 0.8250 -Validation Accuracy: 0.5116
# Epoch 49, CIFAR-10 Batch 1:  Cost :0.61998, Accuracy on Training 0.7500 -Validation Accuracy: 0.5180
# Epoch 50, CIFAR-10 Batch 1:  Cost :0.57028, Accuracy on Training 0.8500 -Validation Accuracy: 0.5182

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Cost :2.27794, Accuracy on Training 0.2250 -Validation Accuracy: 0.1696
# Epoch  1, CIFAR-10 Batch 2:  Cost :2.23194, Accuracy on Training 0.1250 -Validation Accuracy: 0.1714
# Epoch  1, CIFAR-10 Batch 3:  Cost :2.12734, Accuracy on Training 0.3250 -Validation Accuracy: 0.2044
# Epoch  1, CIFAR-10 Batch 4:  Cost :2.07448, Accuracy on Training 0.2250 -Validation Accuracy: 0.2160
# Epoch  1, CIFAR-10 Batch 5:  Cost :1.95728, Accuracy on Training 0.2000 -Validation Accuracy: 0.2422
# Epoch  2, CIFAR-10 Batch 1:  Cost :1.99853, Accuracy on Training 0.2500 -Validation Accuracy: 0.2614
# Epoch  2, CIFAR-10 Batch 2:  Cost :1.87822, Accuracy on Training 0.3250 -Validation Accuracy: 0.2930
# Epoch  2, CIFAR-10 Batch 3:  Cost :1.62319, Accuracy on Training 0.3750 -Validation Accuracy: 0.3170
# Epoch  2, CIFAR-10 Batch 4:  Cost :1.66905, Accuracy on Training 0.3500 -Validation Accuracy: 0.3164
# Epoch  2, CIFAR-10 Batch 5:  Cost :1.67990, Accuracy on Training 0.3750 -Validation Accuracy: 0.3602
# Epoch  3, CIFAR-10 Batch 1:  Cost :1.81784, Accuracy on Training 0.5000 -Validation Accuracy: 0.3668
# Epoch  3, CIFAR-10 Batch 2:  Cost :1.66861, Accuracy on Training 0.3500 -Validation Accuracy: 0.3862
# Epoch  3, CIFAR-10 Batch 3:  Cost :1.41971, Accuracy on Training 0.4250 -Validation Accuracy: 0.3826
# Epoch  3, CIFAR-10 Batch 4:  Cost :1.52491, Accuracy on Training 0.3750 -Validation Accuracy: 0.3882
# Epoch  3, CIFAR-10 Batch 5:  Cost :1.57966, Accuracy on Training 0.4500 -Validation Accuracy: 0.3996
# Epoch  4, CIFAR-10 Batch 1:  Cost :1.70423, Accuracy on Training 0.4250 -Validation Accuracy: 0.4138
# Epoch  4, CIFAR-10 Batch 2:  Cost :1.53366, Accuracy on Training 0.5500 -Validation Accuracy: 0.4310
# Epoch  4, CIFAR-10 Batch 3:  Cost :1.27425, Accuracy on Training 0.6000 -Validation Accuracy: 0.4278
# Epoch  4, CIFAR-10 Batch 4:  Cost :1.47314, Accuracy on Training 0.3500 -Validation Accuracy: 0.4194
# Epoch  4, CIFAR-10 Batch 5:  Cost :1.42701, Accuracy on Training 0.4500 -Validation Accuracy: 0.4410
# Epoch  5, CIFAR-10 Batch 1:  Cost :1.63911, Accuracy on Training 0.4000 -Validation Accuracy: 0.4328
# Epoch  5, CIFAR-10 Batch 2:  Cost :1.47537, Accuracy on Training 0.5000 -Validation Accuracy: 0.4496
# Epoch  5, CIFAR-10 Batch 3:  Cost :1.20950, Accuracy on Training 0.5500 -Validation Accuracy: 0.4358
# Epoch  5, CIFAR-10 Batch 4:  Cost :1.40225, Accuracy on Training 0.4000 -Validation Accuracy: 0.4440
# Epoch  5, CIFAR-10 Batch 5:  Cost :1.31009, Accuracy on Training 0.5500 -Validation Accuracy: 0.4532
# Epoch  6, CIFAR-10 Batch 1:  Cost :1.46658, Accuracy on Training 0.4500 -Validation Accuracy: 0.4840
# Epoch  6, CIFAR-10 Batch 2:  Cost :1.33820, Accuracy on Training 0.5000 -Validation Accuracy: 0.4838
# Epoch  6, CIFAR-10 Batch 3:  Cost :1.16403, Accuracy on Training 0.6250 -Validation Accuracy: 0.4804
# Epoch  6, CIFAR-10 Batch 4:  Cost :1.32677, Accuracy on Training 0.4750 -Validation Accuracy: 0.4730
# Epoch  6, CIFAR-10 Batch 5:  Cost :1.22886, Accuracy on Training 0.5000 -Validation Accuracy: 0.4896
# Epoch  7, CIFAR-10 Batch 1:  Cost :1.36694, Accuracy on Training 0.4750 -Validation Accuracy: 0.4994
# Epoch  7, CIFAR-10 Batch 2:  Cost :1.23785, Accuracy on Training 0.5250 -Validation Accuracy: 0.5078
# Epoch  7, CIFAR-10 Batch 3:  Cost :1.06413, Accuracy on Training 0.6250 -Validation Accuracy: 0.4980
# Epoch  7, CIFAR-10 Batch 4:  Cost :1.21864, Accuracy on Training 0.5500 -Validation Accuracy: 0.4994
# Epoch  7, CIFAR-10 Batch 5:  Cost :1.16449, Accuracy on Training 0.6250 -Validation Accuracy: 0.5218
# Epoch  8, CIFAR-10 Batch 1:  Cost :1.26553, Accuracy on Training 0.5250 -Validation Accuracy: 0.5216
# Epoch  8, CIFAR-10 Batch 2:  Cost :1.16972, Accuracy on Training 0.5250 -Validation Accuracy: 0.5274
# Epoch  8, CIFAR-10 Batch 3:  Cost :0.97924, Accuracy on Training 0.6500 -Validation Accuracy: 0.5202
# Epoch  8, CIFAR-10 Batch 4:  Cost :1.13119, Accuracy on Training 0.7000 -Validation Accuracy: 0.5260
# Epoch  8, CIFAR-10 Batch 5:  Cost :1.04499, Accuracy on Training 0.6750 -Validation Accuracy: 0.5314
# Epoch  9, CIFAR-10 Batch 1:  Cost :1.17544, Accuracy on Training 0.5500 -Validation Accuracy: 0.5444
# Epoch  9, CIFAR-10 Batch 2:  Cost :1.08023, Accuracy on Training 0.5750 -Validation Accuracy: 0.5446
# Epoch  9, CIFAR-10 Batch 3:  Cost :0.96177, Accuracy on Training 0.6750 -Validation Accuracy: 0.5394
# Epoch  9, CIFAR-10 Batch 4:  Cost :1.04674, Accuracy on Training 0.6000 -Validation Accuracy: 0.5380
# Epoch  9, CIFAR-10 Batch 5:  Cost :0.99797, Accuracy on Training 0.6250 -Validation Accuracy: 0.5476
# Epoch 10, CIFAR-10 Batch 1:  Cost :1.09462, Accuracy on Training 0.6500 -Validation Accuracy: 0.5522
# Epoch 10, CIFAR-10 Batch 2:  Cost :1.01497, Accuracy on Training 0.5750 -Validation Accuracy: 0.5534
# Epoch 10, CIFAR-10 Batch 3:  Cost :0.87696, Accuracy on Training 0.7250 -Validation Accuracy: 0.5552
# Epoch 10, CIFAR-10 Batch 4:  Cost :1.03237, Accuracy on Training 0.7250 -Validation Accuracy: 0.5480
# Epoch 10, CIFAR-10 Batch 5:  Cost :0.89271, Accuracy on Training 0.6750 -Validation Accuracy: 0.5560
# Epoch 11, CIFAR-10 Batch 1:  Cost :1.02240, Accuracy on Training 0.7000 -Validation Accuracy: 0.5498
# Epoch 11, CIFAR-10 Batch 2:  Cost :0.98026, Accuracy on Training 0.6000 -Validation Accuracy: 0.5470
# Epoch 11, CIFAR-10 Batch 3:  Cost :0.86089, Accuracy on Training 0.6750 -Validation Accuracy: 0.5568
# Epoch 11, CIFAR-10 Batch 4:  Cost :0.95952, Accuracy on Training 0.7000 -Validation Accuracy: 0.5642
# Epoch 11, CIFAR-10 Batch 5:  Cost :0.83892, Accuracy on Training 0.7000 -Validation Accuracy: 0.5778
# Epoch 12, CIFAR-10 Batch 1:  Cost :0.98726, Accuracy on Training 0.7000 -Validation Accuracy: 0.5602
# Epoch 12, CIFAR-10 Batch 2:  Cost :0.91223, Accuracy on Training 0.6500 -Validation Accuracy: 0.5596
# Epoch 12, CIFAR-10 Batch 3:  Cost :0.83825, Accuracy on Training 0.7500 -Validation Accuracy: 0.5640
# Epoch 12, CIFAR-10 Batch 4:  Cost :0.92282, Accuracy on Training 0.6500 -Validation Accuracy: 0.5778
# Epoch 12, CIFAR-10 Batch 5:  Cost :0.79822, Accuracy on Training 0.7750 -Validation Accuracy: 0.5814
# Epoch 13, CIFAR-10 Batch 1:  Cost :0.91380, Accuracy on Training 0.7000 -Validation Accuracy: 0.5792
# Epoch 13, CIFAR-10 Batch 2:  Cost :0.84141, Accuracy on Training 0.6500 -Validation Accuracy: 0.5722
# Epoch 13, CIFAR-10 Batch 3:  Cost :0.73617, Accuracy on Training 0.7750 -Validation Accuracy: 0.5782
# Epoch 13, CIFAR-10 Batch 4:  Cost :0.84228, Accuracy on Training 0.8000 -Validation Accuracy: 0.5840
# Epoch 13, CIFAR-10 Batch 5:  Cost :0.76205, Accuracy on Training 0.8250 -Validation Accuracy: 0.5900
# Epoch 14, CIFAR-10 Batch 1:  Cost :0.84930, Accuracy on Training 0.7750 -Validation Accuracy: 0.5784
# Epoch 14, CIFAR-10 Batch 2:  Cost :0.75277, Accuracy on Training 0.7000 -Validation Accuracy: 0.5858
# Epoch 14, CIFAR-10 Batch 3:  Cost :0.70729, Accuracy on Training 0.8000 -Validation Accuracy: 0.5826
# Epoch 14, CIFAR-10 Batch 4:  Cost :0.82398, Accuracy on Training 0.7000 -Validation Accuracy: 0.5896
# Epoch 14, CIFAR-10 Batch 5:  Cost :0.73319, Accuracy on Training 0.7500 -Validation Accuracy: 0.5862
# Epoch 15, CIFAR-10 Batch 1:  Cost :0.87183, Accuracy on Training 0.7250 -Validation Accuracy: 0.5840
# Epoch 15, CIFAR-10 Batch 2:  Cost :0.71745, Accuracy on Training 0.7000 -Validation Accuracy: 0.5928
# Epoch 15, CIFAR-10 Batch 3:  Cost :0.65942, Accuracy on Training 0.8500 -Validation Accuracy: 0.5870
# Epoch 15, CIFAR-10 Batch 4:  Cost :0.77454, Accuracy on Training 0.8250 -Validation Accuracy: 0.6050
# Epoch 15, CIFAR-10 Batch 5:  Cost :0.72784, Accuracy on Training 0.8250 -Validation Accuracy: 0.6062
# Epoch 16, CIFAR-10 Batch 1:  Cost :0.80774, Accuracy on Training 0.7250 -Validation Accuracy: 0.6010
# Epoch 16, CIFAR-10 Batch 2:  Cost :0.68887, Accuracy on Training 0.7250 -Validation Accuracy: 0.6002
# Epoch 16, CIFAR-10 Batch 3:  Cost :0.64084, Accuracy on Training 0.8000 -Validation Accuracy: 0.5806
# Epoch 16, CIFAR-10 Batch 4:  Cost :0.74816, Accuracy on Training 0.8250 -Validation Accuracy: 0.6176
# Epoch 16, CIFAR-10 Batch 5:  Cost :0.68818, Accuracy on Training 0.7500 -Validation Accuracy: 0.6122
# Epoch 17, CIFAR-10 Batch 1:  Cost :0.79567, Accuracy on Training 0.7250 -Validation Accuracy: 0.6014
# Epoch 17, CIFAR-10 Batch 2:  Cost :0.64357, Accuracy on Training 0.7750 -Validation Accuracy: 0.6048
# Epoch 17, CIFAR-10 Batch 3:  Cost :0.56281, Accuracy on Training 0.7750 -Validation Accuracy: 0.5814
# Epoch 17, CIFAR-10 Batch 4:  Cost :0.75055, Accuracy on Training 0.7750 -Validation Accuracy: 0.6126
# Epoch 17, CIFAR-10 Batch 5:  Cost :0.64560, Accuracy on Training 0.7500 -Validation Accuracy: 0.6142
# Epoch 18, CIFAR-10 Batch 1:  Cost :0.75295, Accuracy on Training 0.7500 -Validation Accuracy: 0.6160
# Epoch 18, CIFAR-10 Batch 2:  Cost :0.62803, Accuracy on Training 0.8000 -Validation Accuracy: 0.5956
# Epoch 18, CIFAR-10 Batch 3:  Cost :0.56654, Accuracy on Training 0.8500 -Validation Accuracy: 0.6024
# Epoch 18, CIFAR-10 Batch 4:  Cost :0.71869, Accuracy on Training 0.7750 -Validation Accuracy: 0.6134
# Epoch 18, CIFAR-10 Batch 5:  Cost :0.69664, Accuracy on Training 0.7000 -Validation Accuracy: 0.6130
# Epoch 19, CIFAR-10 Batch 1:  Cost :0.75151, Accuracy on Training 0.7250 -Validation Accuracy: 0.6194
# Epoch 19, CIFAR-10 Batch 2:  Cost :0.60302, Accuracy on Training 0.8500 -Validation Accuracy: 0.6048
# Epoch 19, CIFAR-10 Batch 3:  Cost :0.60106, Accuracy on Training 0.9250 -Validation Accuracy: 0.6160
# Epoch 19, CIFAR-10 Batch 4:  Cost :0.72788, Accuracy on Training 0.8250 -Validation Accuracy: 0.6174
# Epoch 19, CIFAR-10 Batch 5:  Cost :0.65022, Accuracy on Training 0.8000 -Validation Accuracy: 0.6248
# Epoch 20, CIFAR-10 Batch 1:  Cost :0.70816, Accuracy on Training 0.7500 -Validation Accuracy: 0.6160
# Epoch 20, CIFAR-10 Batch 2:  Cost :0.55590, Accuracy on Training 0.8750 -Validation Accuracy: 0.6184
# Epoch 20, CIFAR-10 Batch 3:  Cost :0.50757, Accuracy on Training 0.9000 -Validation Accuracy: 0.6224
# Epoch 20, CIFAR-10 Batch 4:  Cost :0.65720, Accuracy on Training 0.8500 -Validation Accuracy: 0.6266
# Epoch 20, CIFAR-10 Batch 5:  Cost :0.61857, Accuracy on Training 0.7750 -Validation Accuracy: 0.6180
# Epoch 21, CIFAR-10 Batch 1:  Cost :0.68138, Accuracy on Training 0.7250 -Validation Accuracy: 0.6294
# Epoch 21, CIFAR-10 Batch 2:  Cost :0.58617, Accuracy on Training 0.8000 -Validation Accuracy: 0.6126
# Epoch 21, CIFAR-10 Batch 3:  Cost :0.53551, Accuracy on Training 0.8750 -Validation Accuracy: 0.6214
# Epoch 21, CIFAR-10 Batch 4:  Cost :0.60771, Accuracy on Training 0.8750 -Validation Accuracy: 0.6312
# Epoch 21, CIFAR-10 Batch 5:  Cost :0.56908, Accuracy on Training 0.8000 -Validation Accuracy: 0.6282
# Epoch 22, CIFAR-10 Batch 1:  Cost :0.67586, Accuracy on Training 0.7750 -Validation Accuracy: 0.6228
# Epoch 22, CIFAR-10 Batch 2:  Cost :0.53646, Accuracy on Training 0.8000 -Validation Accuracy: 0.6216
# Epoch 22, CIFAR-10 Batch 3:  Cost :0.46131, Accuracy on Training 0.9000 -Validation Accuracy: 0.6280
# Epoch 22, CIFAR-10 Batch 4:  Cost :0.61002, Accuracy on Training 0.8250 -Validation Accuracy: 0.6342
# Epoch 22, CIFAR-10 Batch 5:  Cost :0.55851, Accuracy on Training 0.8000 -Validation Accuracy: 0.6270
# Epoch 23, CIFAR-10 Batch 1:  Cost :0.64996, Accuracy on Training 0.7750 -Validation Accuracy: 0.6310
# Epoch 23, CIFAR-10 Batch 2:  Cost :0.51042, Accuracy on Training 0.8250 -Validation Accuracy: 0.6236
# Epoch 23, CIFAR-10 Batch 3:  Cost :0.45493, Accuracy on Training 0.9250 -Validation Accuracy: 0.6274
# Epoch 23, CIFAR-10 Batch 4:  Cost :0.56817, Accuracy on Training 0.9000 -Validation Accuracy: 0.6318
# Epoch 23, CIFAR-10 Batch 5:  Cost :0.53635, Accuracy on Training 0.8000 -Validation Accuracy: 0.6376
# Epoch 24, CIFAR-10 Batch 1:  Cost :0.63095, Accuracy on Training 0.7500 -Validation Accuracy: 0.6250
# Epoch 24, CIFAR-10 Batch 2:  Cost :0.48998, Accuracy on Training 0.8250 -Validation Accuracy: 0.6208
# Epoch 24, CIFAR-10 Batch 3:  Cost :0.41532, Accuracy on Training 0.9500 -Validation Accuracy: 0.6378
# Epoch 24, CIFAR-10 Batch 4:  Cost :0.58273, Accuracy on Training 0.8500 -Validation Accuracy: 0.6426
# Epoch 24, CIFAR-10 Batch 5:  Cost :0.53782, Accuracy on Training 0.8250 -Validation Accuracy: 0.6288
# Epoch 25, CIFAR-10 Batch 1:  Cost :0.62500, Accuracy on Training 0.7250 -Validation Accuracy: 0.6324
# Epoch 25, CIFAR-10 Batch 2:  Cost :0.47818, Accuracy on Training 0.8250 -Validation Accuracy: 0.6230
# Epoch 25, CIFAR-10 Batch 3:  Cost :0.38240, Accuracy on Training 0.9000 -Validation Accuracy: 0.6408
# Epoch 25, CIFAR-10 Batch 4:  Cost :0.54907, Accuracy on Training 0.9250 -Validation Accuracy: 0.6376
# Epoch 25, CIFAR-10 Batch 5:  Cost :0.50232, Accuracy on Training 0.8500 -Validation Accuracy: 0.6498
# Epoch 26, CIFAR-10 Batch 1:  Cost :0.60353, Accuracy on Training 0.7750 -Validation Accuracy: 0.6316
# Epoch 26, CIFAR-10 Batch 2:  Cost :0.45322, Accuracy on Training 0.9000 -Validation Accuracy: 0.6358
# Epoch 26, CIFAR-10 Batch 3:  Cost :0.37054, Accuracy on Training 0.9750 -Validation Accuracy: 0.6462
# Epoch 26, CIFAR-10 Batch 4:  Cost :0.48587, Accuracy on Training 0.9250 -Validation Accuracy: 0.6542
# Epoch 26, CIFAR-10 Batch 5:  Cost :0.45589, Accuracy on Training 0.8750 -Validation Accuracy: 0.6394
# Epoch 27, CIFAR-10 Batch 1:  Cost :0.55344, Accuracy on Training 0.8250 -Validation Accuracy: 0.6412
# Epoch 27, CIFAR-10 Batch 2:  Cost :0.43735, Accuracy on Training 0.8750 -Validation Accuracy: 0.6430
# Epoch 27, CIFAR-10 Batch 3:  Cost :0.37094, Accuracy on Training 0.9500 -Validation Accuracy: 0.6438
# Epoch 27, CIFAR-10 Batch 4:  Cost :0.48658, Accuracy on Training 0.9000 -Validation Accuracy: 0.6492
# Epoch 27, CIFAR-10 Batch 5:  Cost :0.42582, Accuracy on Training 0.8750 -Validation Accuracy: 0.6494
# Epoch 28, CIFAR-10 Batch 1:  Cost :0.59150, Accuracy on Training 0.8000 -Validation Accuracy: 0.6494
# Epoch 28, CIFAR-10 Batch 2:  Cost :0.39220, Accuracy on Training 0.8750 -Validation Accuracy: 0.6428
# Epoch 28, CIFAR-10 Batch 3:  Cost :0.35159, Accuracy on Training 0.9500 -Validation Accuracy: 0.6462
# Epoch 28, CIFAR-10 Batch 4:  Cost :0.48245, Accuracy on Training 0.9250 -Validation Accuracy: 0.6418
# Epoch 28, CIFAR-10 Batch 5:  Cost :0.45189, Accuracy on Training 0.9000 -Validation Accuracy: 0.6476
# Epoch 29, CIFAR-10 Batch 1:  Cost :0.58352, Accuracy on Training 0.7750 -Validation Accuracy: 0.6496
# Epoch 29, CIFAR-10 Batch 2:  Cost :0.39309, Accuracy on Training 0.9000 -Validation Accuracy: 0.6420
# Epoch 29, CIFAR-10 Batch 3:  Cost :0.33312, Accuracy on Training 0.9500 -Validation Accuracy: 0.6466
# Epoch 29, CIFAR-10 Batch 4:  Cost :0.45441, Accuracy on Training 0.9000 -Validation Accuracy: 0.6540
# Epoch 29, CIFAR-10 Batch 5:  Cost :0.44301, Accuracy on Training 0.9500 -Validation Accuracy: 0.6520
# Epoch 30, CIFAR-10 Batch 1:  Cost :0.56128, Accuracy on Training 0.7750 -Validation Accuracy: 0.6438
# Epoch 30, CIFAR-10 Batch 2:  Cost :0.38118, Accuracy on Training 0.9500 -Validation Accuracy: 0.6508
# Epoch 30, CIFAR-10 Batch 3:  Cost :0.32555, Accuracy on Training 0.9750 -Validation Accuracy: 0.6494
# Epoch 30, CIFAR-10 Batch 4:  Cost :0.44456, Accuracy on Training 0.9250 -Validation Accuracy: 0.6466
# Epoch 30, CIFAR-10 Batch 5:  Cost :0.41878, Accuracy on Training 0.9500 -Validation Accuracy: 0.6434
# Epoch 31, CIFAR-10 Batch 1:  Cost :0.53185, Accuracy on Training 0.8000 -Validation Accuracy: 0.6594
# Epoch 31, CIFAR-10 Batch 2:  Cost :0.39544, Accuracy on Training 0.8750 -Validation Accuracy: 0.6348
# Epoch 31, CIFAR-10 Batch 3:  Cost :0.32732, Accuracy on Training 0.9750 -Validation Accuracy: 0.6536
# Epoch 31, CIFAR-10 Batch 4:  Cost :0.41348, Accuracy on Training 0.9250 -Validation Accuracy: 0.6530
# Epoch 31, CIFAR-10 Batch 5:  Cost :0.38019, Accuracy on Training 0.9750 -Validation Accuracy: 0.6510
# Epoch 32, CIFAR-10 Batch 1:  Cost :0.46958, Accuracy on Training 0.8250 -Validation Accuracy: 0.6428
# Epoch 32, CIFAR-10 Batch 2:  Cost :0.36146, Accuracy on Training 0.9000 -Validation Accuracy: 0.6490
# Epoch 32, CIFAR-10 Batch 3:  Cost :0.31920, Accuracy on Training 0.9500 -Validation Accuracy: 0.6524
# Epoch 32, CIFAR-10 Batch 4:  Cost :0.39911, Accuracy on Training 0.9500 -Validation Accuracy: 0.6626
# Epoch 32, CIFAR-10 Batch 5:  Cost :0.38402, Accuracy on Training 0.9250 -Validation Accuracy: 0.6522
# Epoch 33, CIFAR-10 Batch 1:  Cost :0.46626, Accuracy on Training 0.9000 -Validation Accuracy: 0.6544
# Epoch 33, CIFAR-10 Batch 2:  Cost :0.35177, Accuracy on Training 0.9250 -Validation Accuracy: 0.6472
# Epoch 33, CIFAR-10 Batch 3:  Cost :0.28792, Accuracy on Training 0.9500 -Validation Accuracy: 0.6478
# Epoch 33, CIFAR-10 Batch 4:  Cost :0.39908, Accuracy on Training 0.9500 -Validation Accuracy: 0.6516
# Epoch 33, CIFAR-10 Batch 5:  Cost :0.35594, Accuracy on Training 0.9750 -Validation Accuracy: 0.6448
# Epoch 34, CIFAR-10 Batch 1:  Cost :0.46034, Accuracy on Training 0.8750 -Validation Accuracy: 0.6588
# Epoch 34, CIFAR-10 Batch 2:  Cost :0.36601, Accuracy on Training 0.9000 -Validation Accuracy: 0.6502
# Epoch 34, CIFAR-10 Batch 3:  Cost :0.27915, Accuracy on Training 0.9750 -Validation Accuracy: 0.6594
# Epoch 34, CIFAR-10 Batch 4:  Cost :0.38493, Accuracy on Training 0.9500 -Validation Accuracy: 0.6528
# Epoch 34, CIFAR-10 Batch 5:  Cost :0.37189, Accuracy on Training 0.9500 -Validation Accuracy: 0.6548
# Epoch 35, CIFAR-10 Batch 1:  Cost :0.47202, Accuracy on Training 0.8750 -Validation Accuracy: 0.6544
# Epoch 35, CIFAR-10 Batch 2:  Cost :0.35773, Accuracy on Training 0.9250 -Validation Accuracy: 0.6472
# Epoch 35, CIFAR-10 Batch 3:  Cost :0.26468, Accuracy on Training 1.0000 -Validation Accuracy: 0.6544
# Epoch 35, CIFAR-10 Batch 4:  Cost :0.39564, Accuracy on Training 0.9750 -Validation Accuracy: 0.6508
# Epoch 35, CIFAR-10 Batch 5:  Cost :0.34180, Accuracy on Training 1.0000 -Validation Accuracy: 0.6516
# Epoch 36, CIFAR-10 Batch 1:  Cost :0.47946, Accuracy on Training 0.8500 -Validation Accuracy: 0.6616
# Epoch 36, CIFAR-10 Batch 2:  Cost :0.33792, Accuracy on Training 0.9000 -Validation Accuracy: 0.6614
# Epoch 36, CIFAR-10 Batch 3:  Cost :0.27524, Accuracy on Training 0.9750 -Validation Accuracy: 0.6564
# Epoch 36, CIFAR-10 Batch 4:  Cost :0.37961, Accuracy on Training 0.9750 -Validation Accuracy: 0.6582
# Epoch 36, CIFAR-10 Batch 5:  Cost :0.34942, Accuracy on Training 0.9750 -Validation Accuracy: 0.6544
# Epoch 37, CIFAR-10 Batch 1:  Cost :0.47036, Accuracy on Training 0.8500 -Validation Accuracy: 0.6612
# Epoch 37, CIFAR-10 Batch 2:  Cost :0.32985, Accuracy on Training 0.9250 -Validation Accuracy: 0.6548
# Epoch 37, CIFAR-10 Batch 3:  Cost :0.23125, Accuracy on Training 1.0000 -Validation Accuracy: 0.6650
# Epoch 37, CIFAR-10 Batch 4:  Cost :0.36654, Accuracy on Training 0.9500 -Validation Accuracy: 0.6602
# Epoch 37, CIFAR-10 Batch 5:  Cost :0.33194, Accuracy on Training 0.9500 -Validation Accuracy: 0.6532
# Epoch 38, CIFAR-10 Batch 1:  Cost :0.47325, Accuracy on Training 0.9000 -Validation Accuracy: 0.6614
# Epoch 38, CIFAR-10 Batch 2:  Cost :0.34523, Accuracy on Training 0.8750 -Validation Accuracy: 0.6620
# Epoch 38, CIFAR-10 Batch 3:  Cost :0.22574, Accuracy on Training 0.9750 -Validation Accuracy: 0.6598
# Epoch 38, CIFAR-10 Batch 4:  Cost :0.34090, Accuracy on Training 0.9500 -Validation Accuracy: 0.6630
# Epoch 38, CIFAR-10 Batch 5:  Cost :0.29341, Accuracy on Training 1.0000 -Validation Accuracy: 0.6568
# Epoch 39, CIFAR-10 Batch 1:  Cost :0.43257, Accuracy on Training 0.9250 -Validation Accuracy: 0.6600
# Epoch 39, CIFAR-10 Batch 2:  Cost :0.36176, Accuracy on Training 0.9000 -Validation Accuracy: 0.6462
# Epoch 39, CIFAR-10 Batch 3:  Cost :0.20922, Accuracy on Training 0.9750 -Validation Accuracy: 0.6538
# Epoch 39, CIFAR-10 Batch 4:  Cost :0.34657, Accuracy on Training 0.9500 -Validation Accuracy: 0.6578
# Epoch 39, CIFAR-10 Batch 5:  Cost :0.30074, Accuracy on Training 0.9750 -Validation Accuracy: 0.6616
# Epoch 40, CIFAR-10 Batch 1:  Cost :0.43795, Accuracy on Training 0.9250 -Validation Accuracy: 0.6544
# Epoch 40, CIFAR-10 Batch 2:  Cost :0.34696, Accuracy on Training 0.9000 -Validation Accuracy: 0.6610
# Epoch 40, CIFAR-10 Batch 3:  Cost :0.23322, Accuracy on Training 0.9750 -Validation Accuracy: 0.6584
# Epoch 40, CIFAR-10 Batch 4:  Cost :0.32555, Accuracy on Training 0.9750 -Validation Accuracy: 0.6476
# Epoch 40, CIFAR-10 Batch 5:  Cost :0.28834, Accuracy on Training 1.0000 -Validation Accuracy: 0.6482
# Epoch 41, CIFAR-10 Batch 1:  Cost :0.42681, Accuracy on Training 0.8500 -Validation Accuracy: 0.6590
# Epoch 41, CIFAR-10 Batch 2:  Cost :0.34693, Accuracy on Training 0.8750 -Validation Accuracy: 0.6416
# Epoch 41, CIFAR-10 Batch 3:  Cost :0.22834, Accuracy on Training 0.9750 -Validation Accuracy: 0.6668
# Epoch 41, CIFAR-10 Batch 4:  Cost :0.31913, Accuracy on Training 0.9500 -Validation Accuracy: 0.6568
# Epoch 41, CIFAR-10 Batch 5:  Cost :0.26491, Accuracy on Training 1.0000 -Validation Accuracy: 0.6544
# Epoch 42, CIFAR-10 Batch 1:  Cost :0.45036, Accuracy on Training 0.8750 -Validation Accuracy: 0.6680
# Epoch 42, CIFAR-10 Batch 2:  Cost :0.32577, Accuracy on Training 0.9000 -Validation Accuracy: 0.6648
# Epoch 42, CIFAR-10 Batch 3:  Cost :0.20612, Accuracy on Training 1.0000 -Validation Accuracy: 0.6642
# Epoch 42, CIFAR-10 Batch 4:  Cost :0.32354, Accuracy on Training 0.9750 -Validation Accuracy: 0.6634
# Epoch 42, CIFAR-10 Batch 5:  Cost :0.30131, Accuracy on Training 0.9750 -Validation Accuracy: 0.6614
# Epoch 43, CIFAR-10 Batch 1:  Cost :0.40369, Accuracy on Training 0.8500 -Validation Accuracy: 0.6658
# Epoch 43, CIFAR-10 Batch 2:  Cost :0.31934, Accuracy on Training 0.9250 -Validation Accuracy: 0.6590
# Epoch 43, CIFAR-10 Batch 3:  Cost :0.21815, Accuracy on Training 0.9750 -Validation Accuracy: 0.6626
# Epoch 43, CIFAR-10 Batch 4:  Cost :0.32946, Accuracy on Training 0.9750 -Validation Accuracy: 0.6448
# Epoch 43, CIFAR-10 Batch 5:  Cost :0.28163, Accuracy on Training 1.0000 -Validation Accuracy: 0.6574
# Epoch 44, CIFAR-10 Batch 1:  Cost :0.39937, Accuracy on Training 0.8750 -Validation Accuracy: 0.6736
# Epoch 44, CIFAR-10 Batch 2:  Cost :0.30397, Accuracy on Training 0.9500 -Validation Accuracy: 0.6672
# Epoch 44, CIFAR-10 Batch 3:  Cost :0.19416, Accuracy on Training 0.9750 -Validation Accuracy: 0.6614
# Epoch 44, CIFAR-10 Batch 4:  Cost :0.31433, Accuracy on Training 0.9750 -Validation Accuracy: 0.6602
# Epoch 44, CIFAR-10 Batch 5:  Cost :0.27867, Accuracy on Training 0.9750 -Validation Accuracy: 0.6622
# Epoch 45, CIFAR-10 Batch 1:  Cost :0.40645, Accuracy on Training 0.8500 -Validation Accuracy: 0.6668
# Epoch 45, CIFAR-10 Batch 2:  Cost :0.30301, Accuracy on Training 0.9500 -Validation Accuracy: 0.6700
# Epoch 45, CIFAR-10 Batch 3:  Cost :0.18616, Accuracy on Training 1.0000 -Validation Accuracy: 0.6688
# Epoch 45, CIFAR-10 Batch 4:  Cost :0.30137, Accuracy on Training 0.9500 -Validation Accuracy: 0.6640
# Epoch 45, CIFAR-10 Batch 5:  Cost :0.27673, Accuracy on Training 0.9750 -Validation Accuracy: 0.6630
# Epoch 46, CIFAR-10 Batch 1:  Cost :0.39433, Accuracy on Training 0.8250 -Validation Accuracy: 0.6674
# Epoch 46, CIFAR-10 Batch 2:  Cost :0.29834, Accuracy on Training 0.9500 -Validation Accuracy: 0.6726
# Epoch 46, CIFAR-10 Batch 3:  Cost :0.20654, Accuracy on Training 0.9750 -Validation Accuracy: 0.6548
# Epoch 46, CIFAR-10 Batch 4:  Cost :0.29151, Accuracy on Training 0.9750 -Validation Accuracy: 0.6596
# Epoch 46, CIFAR-10 Batch 5:  Cost :0.26435, Accuracy on Training 1.0000 -Validation Accuracy: 0.6572
# Epoch 47, CIFAR-10 Batch 1:  Cost :0.40578, Accuracy on Training 0.9000 -Validation Accuracy: 0.6626
# Epoch 47, CIFAR-10 Batch 2:  Cost :0.31541, Accuracy on Training 0.9250 -Validation Accuracy: 0.6746
# Epoch 47, CIFAR-10 Batch 3:  Cost :0.18550, Accuracy on Training 0.9750 -Validation Accuracy: 0.6574
# Epoch 47, CIFAR-10 Batch 4:  Cost :0.30333, Accuracy on Training 0.9750 -Validation Accuracy: 0.6676
# Epoch 47, CIFAR-10 Batch 5:  Cost :0.26669, Accuracy on Training 0.9750 -Validation Accuracy: 0.6636
# Epoch 48, CIFAR-10 Batch 1:  Cost :0.38180, Accuracy on Training 0.9000 -Validation Accuracy: 0.6650
# Epoch 48, CIFAR-10 Batch 2:  Cost :0.30247, Accuracy on Training 0.9500 -Validation Accuracy: 0.6736
# Epoch 48, CIFAR-10 Batch 3:  Cost :0.18722, Accuracy on Training 0.9750 -Validation Accuracy: 0.6640
# Epoch 48, CIFAR-10 Batch 4:  Cost :0.26941, Accuracy on Training 0.9750 -Validation Accuracy: 0.6654
# Epoch 48, CIFAR-10 Batch 5:  Cost :0.25865, Accuracy on Training 1.0000 -Validation Accuracy: 0.6504
# Epoch 49, CIFAR-10 Batch 1:  Cost :0.40479, Accuracy on Training 0.8750 -Validation Accuracy: 0.6670
# Epoch 49, CIFAR-10 Batch 2:  Cost :0.27405, Accuracy on Training 0.9250 -Validation Accuracy: 0.6682
# Epoch 49, CIFAR-10 Batch 3:  Cost :0.17281, Accuracy on Training 0.9750 -Validation Accuracy: 0.6716
# Epoch 49, CIFAR-10 Batch 4:  Cost :0.27293, Accuracy on Training 0.9750 -Validation Accuracy: 0.6678
# Epoch 49, CIFAR-10 Batch 5:  Cost :0.27189, Accuracy on Training 0.9750 -Validation Accuracy: 0.6574
# Epoch 50, CIFAR-10 Batch 1:  Cost :0.39497, Accuracy on Training 0.8500 -Validation Accuracy: 0.6678
# Epoch 50, CIFAR-10 Batch 2:  Cost :0.28206, Accuracy on Training 0.9500 -Validation Accuracy: 0.6746
# Epoch 50, CIFAR-10 Batch 3:  Cost :0.15642, Accuracy on Training 0.9750 -Validation Accuracy: 0.6660
# Epoch 50, CIFAR-10 Batch 4:  Cost :0.23993, Accuracy on Training 0.9750 -Validation Accuracy: 0.6642
# Epoch 50, CIFAR-10 Batch 5:  Cost :0.26694, Accuracy on Training 0.9750 -Validation Accuracy: 0.6696

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.674609375
